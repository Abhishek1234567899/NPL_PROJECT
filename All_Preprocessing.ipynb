# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("extracted_data_cve_key_data.csv")

# Display the first few rows of the dataframe
print(df.head())
# Out:
#           CVE ID Source Identifier           Published Date  \
# 0  CVE-1999-0001     cve@mitre.org  1999-12-30T05:00:00.000
# 1  CVE-1999-0002     cve@mitre.org  1998-10-12T04:00:00.000
# 2  CVE-1999-0003     cve@mitre.org  1998-04-01T05:00:00.000
# 3  CVE-1999-0004     cve@mitre.org  1997-12-16T05:00:00.000
# 4  CVE-1999-0005     cve@mitre.org  1998-07-20T04:00:00.000
#
#         Last Modified Date Vulnerability Status  \
# 0  2010-12-16T05:00:00.000             Analyzed
# 1  2009-01-26T05:00:00.000             Analyzed
# 2  2018-10-30T16:26:22.357             Analyzed
# 3  2018-10-12T21:29:02.120             Modified
# 4  2008-09-09T12:33:31.117             Analyzed
#
#                                          Description  CVSS Score  \
# 0  ip_input.c in BSD-derived TCP/IP implementatio...         5.0
# 1  Buffer overflow in NFS mountd gives root acces...        10.0
# 2  Execute commands as root via buffer overflow i...        10.0
# 3  MIME buffer overflow in email clients, e.g. So...         5.0
# 4  Arbitrary command execution via IMAP buffer ov...        10.0
#
#       Weaknesses                                      Configuration  \
# 0         CWE-20  cpe:2.3:o:bsdi:bsd_os:3.1:*:*:*:*:*:*:*; cpe:2...
# 1        CWE-119  cpe:2.3:o:bsdi:bsd_os:1.1:*:*:*:*:*:*:*; cpe:2...
# 2  NVD-CWE-Other  cpe:2.3:a:tritreal:ted_cde:4.3:*:*:*:*:*:*:*; ...
# 3  NVD-CWE-Other  cpe:2.3:a:hp:dtmail:*:*:*:*:*:*:*:*; cpe:2.3:a...
# 4  NVD-CWE-Other  cpe:2.3:a:netscape:messaging_server:3.55:*:*:*...
#
#                                           References
# 0  http://www.openbsd.org/errata23.html#tcpfix; h...
# 1  ftp://patches.sgi.com/support/free/security/ad...
# 2  ftp://patches.sgi.com/support/free/security/ad...
# 3  https://docs.microsoft.com/en-us/security-upda...
# 4  http://sunsolve.sun.com/pub-cgi/retrieve.pl?do...

# %%
df
# Out:
#                 CVE ID                     Source Identifier  \
# 0        CVE-1999-0001                         cve@mitre.org
# 1        CVE-1999-0002                         cve@mitre.org
# 2        CVE-1999-0003                         cve@mitre.org
# 3        CVE-1999-0004                         cve@mitre.org
# 4        CVE-1999-0005                         cve@mitre.org
# ...                ...                                   ...
# 238603  CVE-2024-27133                       reefs@jfrog.com
# 238604  CVE-2024-27215                         cve@mitre.org
# 238605  CVE-2024-27283                         cve@mitre.org
# 238606  CVE-2024-27318  6f8de1f0-f67e-45a6-b68f-98777fdb759c
# 238607  CVE-2024-27319  6f8de1f0-f67e-45a6-b68f-98777fdb759c
#
#                  Published Date       Last Modified Date Vulnerability Status  \
# 0       1999-12-30T05:00:00.000  2010-12-16T05:00:00.000             Analyzed
# 1       1998-10-12T04:00:00.000  2009-01-26T05:00:00.000             Analyzed
# 2       1998-04-01T05:00:00.000  2018-10-30T16:26:22.357             Analyzed
# 3       1997-12-16T05:00:00.000  2018-10-12T21:29:02.120             Modified
# 4       1998-07-20T04:00:00.000  2008-09-09T12:33:31.117             Analyzed
# ...                         ...                      ...                  ...
# 238603  2024-02-23T22:15:55.287  2024-02-23T22:15:55.287             Received
# 238604  2024-02-21T16:15:50.657  2024-02-21T18:15:52.060             Rejected
# 238605  2024-02-22T05:15:10.087  2024-02-22T19:07:27.197    Awaiting Analysis
# 238606  2024-02-23T18:15:50.767  2024-02-23T19:31:25.817    Awaiting Analysis
# 238607  2024-02-23T18:15:50.960  2024-02-23T19:31:25.817    Awaiting Analysis
#
#                                               Description  CVSS Score  \
# 0       ip_input.c in BSD-derived TCP/IP implementatio...         5.0
# 1       Buffer overflow in NFS mountd gives root acces...        10.0
# 2       Execute commands as root via buffer overflow i...        10.0
# 3       MIME buffer overflow in email clients, e.g. So...         5.0
# 4       Arbitrary command execution via IMAP buffer ov...        10.0
# ...                                                   ...         ...
# 238603  Insufficient sanitization in MLflow leads to X...         NaN
# 238604  Rejected reason: DO NOT USE THIS CANDIDATE NUM...         NaN
# 238605  A vulnerability was discovered in Veritas eDis...         NaN
# 238606  Versions of the package onnx before and includ...         NaN
# 238607  Versions of the package onnx before and includ...         NaN
#
#            Weaknesses                                      Configuration  \
# 0              CWE-20  cpe:2.3:o:bsdi:bsd_os:3.1:*:*:*:*:*:*:*; cpe:2...
# 1             CWE-119  cpe:2.3:o:bsdi:bsd_os:1.1:*:*:*:*:*:*:*; cpe:2...
# 2       NVD-CWE-Other  cpe:2.3:a:tritreal:ted_cde:4.3:*:*:*:*:*:*:*; ...
# 3       NVD-CWE-Other  cpe:2.3:a:hp:dtmail:*:*:*:*:*:*:*:*; cpe:2.3:a...
# 4       NVD-CWE-Other  cpe:2.3:a:netscape:messaging_server:3.55:*:*:*...
# ...               ...                                                ...
# 238603         CWE-79                                                NaN
# 238604            NaN                                                NaN
# 238605            NaN                                                NaN
# 238606         CWE-22                                                NaN
# 238607        CWE-125                                                NaN
#
#                                                References
# 0       http://www.openbsd.org/errata23.html#tcpfix; h...
# 1       ftp://patches.sgi.com/support/free/security/ad...
# 2       ftp://patches.sgi.com/support/free/security/ad...
# 3       https://docs.microsoft.com/en-us/security-upda...
# 4       http://sunsolve.sun.com/pub-cgi/retrieve.pl?do...
# ...                                                   ...
# 238603  https://github.com/mlflow/mlflow/pull/10893; h...
# 238604                                                NaN
# 238605  https://www.veritas.com/support/en_US/security...
# 238606  https://github.com/onnx/onnx/commit/66b7fb6309...
# 238607  https://github.com/onnx/onnx/commit/08a399ba75...
#
# [238608 rows x 10 columns]

# %%
df.shape
# Out:
# (238608, 10)

# %%
# !pip install pinecone
# Out:
# Requirement already satisfied: pinecone in e:\maniconda\envs\fai\lib\site-packages (5.3.1)
# Requirement already satisfied: certifi>=2019.11.17 in e:\maniconda\envs\fai\lib\site-packages (from pinecone) (2024.8.30)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.1.0 in e:\maniconda\envs\fai\lib\site-packages (from pinecone) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in e:\maniconda\envs\fai\lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.64.1 in e:\maniconda\envs\fai\lib\site-packages (from pinecone) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in e:\maniconda\envs\fai\lib\site-packages (from pinecone) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.5.3->pinecone) (1.16.0)
# Requirement already satisfied: colorama in c:\users\imaba\appdata\roaming\python\python38\site-packages (from tqdm>=4.64.1->pinecone) (0.4.6)

# %%
import pandas as pd
import re
import requests
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from datetime import datetime
import json
import pinecone
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
# Initialize NLTK resources
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# Define stop words and stemmer
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

# %%
# Step 1: Data Collection (Assuming CSV data is already downloaded)
# Load the CVE data CSV file
df = pd.read_csv("extracted_data_cve_key_data.csv")

# %%
# Step 2: Data Preprocessing
# Preprocessing function for text fields
def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    text = ' '.join([ps.stem(word) for word in text.split() if word not in stop_words])
    return text

# %%
# Apply preprocessing to textual columns
for column in ['Description', 'Weaknesses', 'Configuration', 'References']:
    df[column] = df[column].apply(preprocess_text)

# %%
# Standardize 'CVE ID' and 'Source Identifier'
df['CVE ID'] = df['CVE ID'].str.upper().str.strip()
df['Source Identifier'] = df['Source Identifier'].str.strip()
df['Vulnerability Status'] = df['Vulnerability Status'].str.lower().str.strip()

# %%
# Convert 'CVSS Score' to numeric
df['CVSS Score'] = pd.to_numeric(df['CVSS Score'], errors='coerce')

# %%
# Convert date fields to datetime
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce')
df['Last Modified Date'] = pd.to_datetime(df['Last Modified Date'], errors='coerce')

# %%
# Drop rows missing critical information
df.dropna(subset=['CVE ID', 'Source Identifier', 'Description'], inplace=True)

# %%
# Save preprocessed data for further analysis
df.to_csv("cve_data_preprocessed.csv", index=False)

print("Data Preprocessing Complete!")
# Out:
# Data Preprocessing Complete!

# %%
df
# Out:
#                 CVE ID                     Source Identifier  \
# 0        CVE-1999-0001                         cve@mitre.org
# 1        CVE-1999-0002                         cve@mitre.org
# 2        CVE-1999-0003                         cve@mitre.org
# 3        CVE-1999-0004                         cve@mitre.org
# 4        CVE-1999-0005                         cve@mitre.org
# ...                ...                                   ...
# 238603  CVE-2024-27133                       reefs@jfrog.com
# 238604  CVE-2024-27215                         cve@mitre.org
# 238605  CVE-2024-27283                         cve@mitre.org
# 238606  CVE-2024-27318  6f8de1f0-f67e-45a6-b68f-98777fdb759c
# 238607  CVE-2024-27319  6f8de1f0-f67e-45a6-b68f-98777fdb759c
#
#                 Published Date      Last Modified Date Vulnerability Status  \
# 0      1999-12-30 05:00:00.000 2010-12-16 05:00:00.000             analyzed
# 1      1998-10-12 04:00:00.000 2009-01-26 05:00:00.000             analyzed
# 2      1998-04-01 05:00:00.000 2018-10-30 16:26:22.357             analyzed
# 3      1997-12-16 05:00:00.000 2018-10-12 21:29:02.120             modified
# 4      1998-07-20 04:00:00.000 2008-09-09 12:33:31.117             analyzed
# ...                        ...                     ...                  ...
# 238603 2024-02-23 22:15:55.287 2024-02-23 22:15:55.287             received
# 238604 2024-02-21 16:15:50.657 2024-02-21 18:15:52.060             rejected
# 238605 2024-02-22 05:15:10.087 2024-02-22 19:07:27.197    awaiting analysis
# 238606 2024-02-23 18:15:50.767 2024-02-23 19:31:25.817    awaiting analysis
# 238607 2024-02-23 18:15:50.960 2024-02-23 19:31:25.817    awaiting analysis
#
#                                               Description  CVSS Score  \
# 0       ip_inputc bsdderiv tcpip implement allow remot...         5.0
# 1       buffer overflow nf mountd give root access rem...        10.0
# 2       execut command root via buffer overflow toolta...        10.0
# 3       mime buffer overflow email client eg solari ma...         5.0
# 4       arbitrari command execut via imap buffer overf...        10.0
# ...                                                   ...         ...
# 238603  insuffici sanit mlflow lead xss run recip use ...         NaN
# 238604  reject reason use candid number consultid cve ...         NaN
# 238605  vulner discov verita ediscoveri platform appli...         NaN
# 238606  version packag onnx includ vulner directori tr...         NaN
# 238607  version packag onnx includ vulner outofbound r...         NaN
#
#          Weaknesses                                      Configuration  \
# 0               cwe  cpeobsdibsd_o cpeofreebsdfreebsd cpeofreebsdfr...
# 1               cwe  cpeobsdibsd_o cpeocalderaopenlinux cpeoredhatl...
# 2       nvdcweother  cpeatritrealted_cd cpeosgiirix cpeosgiirix cpe...
# 3       nvdcweother  cpeahpdtmail cpeauniversity_of_washingtonpin c...
# 4       nvdcweother  cpeanetscapemessaging_serv cpeauniversity_of_w...
# ...             ...                                                ...
# 238603          cwe
# 238604
# 238605
# 238606          cwe
# 238607          cwe
#
#                                                References
# 0       httpwwwopenbsdorgerratahtmltcpfix httpwwwosvdborg
# 1       ftppatchessgicomsupportfreesecurityadvisoriesi...
# 2       ftppatchessgicomsupportfreesecurityadvisoriesa...
# 3       httpsdocsmicrosoftcomenussecurityupdatessecuri...
# 4       httpsunsolvesuncompubcgiretrievepldoctypecolld...
# ...                                                   ...
# 238603  httpsgithubcommlflowmlflowpul httpsresearchjfr...
# 238604
# 238605           httpswwwveritascomsupporten_ussecurityvt
# 238606  httpsgithubcomonnxonnxcommitbfbfdcfebbddea htt...
# 238607            httpsgithubcomonnxonnxcommitabaababbdeb
#
# [238608 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Visualize the distribution of CVSS Scores
plt.figure(figsize=(10, 6))
sns.histplot(df['CVSS Score'].dropna(), bins=20, kde=True)
plt.title('Distribution of CVSS Scores')
plt.xlabel('CVSS Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Count the number of vulnerabilities per status
status_counts = df['Vulnerability Status'].value_counts()

# Visualize the number of vulnerabilities per status
plt.figure(figsize=(10, 6))
sns.barplot(x=status_counts.index, y=status_counts.values, palette='viridis')
plt.title('Number of Vulnerabilities by Status')
plt.xlabel('Vulnerability Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\imaba\AppData\Local\Temp\ipykernel_26736\1060323871.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=status_counts.index, y=status_counts.values, palette='viridis')

# %%
# Step 3: Information Extraction (Using Named Entity Recognition)
def extract_entities(text):
    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    entities = ne_chunk(tagged)
    return entities

# %%
import nltk
nltk.download('words')
nltk.download('maxent_ne_chunker')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\imaba\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import spacy

# Load the spaCy model (download if necessary)
nlp = spacy.load("en_core_web_sm")

# Function to extract named entities
def extract_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Apply NER on the 'Description' column
df['Entities'] = df['Description'].apply(extract_entities)

# %% [markdown]
#  Dependency Parsing

# %%
def parse_dependencies(text):
    doc = nlp(text)
    dependencies = [(token.text, token.dep_, token.head.text) for token in doc]
    return dependencies

# Apply dependency parsing on the 'Description' column
df['Dependencies'] = df['Description'].apply(parse_dependencies)

# %% [markdown]
# Text Classification

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Example predefined categories (could be extracted from your data)
categories = ['vulnerability', 'exploit', 'patch', 'configuration']

# Create TF-IDF vectors for categories
vectorizer = TfidfVectorizer()
category_vectors = vectorizer.fit_transform(categories)

# Function to classify based on similarity to predefined categories
def classify_description(description):
    description_vector = vectorizer.transform([description])
    cosine_similarities = cosine_similarity(description_vector, category_vectors)
    most_similar_index = cosine_similarities.argmax()
    return categories[most_similar_index]

# Apply classification
df['Category'] = df['Description'].apply(classify_description)

# %%
# Save the DataFrame to a CSV file
output_file = 'cve_data_with_categories.csv'  # Specify your desired output file name
df.to_csv(output_file, index=False)  # Save the DataFrame without row indices

print(f'DataFrame saved to {output_file}')
# Out:
# DataFrame saved to cve_data_with_categories.csv

# %%
df
# Out:
#                 CVE ID                     Source Identifier  \
# 0        CVE-1999-0001                         cve@mitre.org
# 1        CVE-1999-0002                         cve@mitre.org
# 2        CVE-1999-0003                         cve@mitre.org
# 3        CVE-1999-0004                         cve@mitre.org
# 4        CVE-1999-0005                         cve@mitre.org
# ...                ...                                   ...
# 238603  CVE-2024-27133                       reefs@jfrog.com
# 238604  CVE-2024-27215                         cve@mitre.org
# 238605  CVE-2024-27283                         cve@mitre.org
# 238606  CVE-2024-27318  6f8de1f0-f67e-45a6-b68f-98777fdb759c
# 238607  CVE-2024-27319  6f8de1f0-f67e-45a6-b68f-98777fdb759c
#
#                 Published Date      Last Modified Date Vulnerability Status  \
# 0      1999-12-30 05:00:00.000 2010-12-16 05:00:00.000             analyzed
# 1      1998-10-12 04:00:00.000 2009-01-26 05:00:00.000             analyzed
# 2      1998-04-01 05:00:00.000 2018-10-30 16:26:22.357             analyzed
# 3      1997-12-16 05:00:00.000 2018-10-12 21:29:02.120             modified
# 4      1998-07-20 04:00:00.000 2008-09-09 12:33:31.117             analyzed
# ...                        ...                     ...                  ...
# 238603 2024-02-23 22:15:55.287 2024-02-23 22:15:55.287             received
# 238604 2024-02-21 16:15:50.657 2024-02-21 18:15:52.060             rejected
# 238605 2024-02-22 05:15:10.087 2024-02-22 19:07:27.197    awaiting analysis
# 238606 2024-02-23 18:15:50.767 2024-02-23 19:31:25.817    awaiting analysis
# 238607 2024-02-23 18:15:50.960 2024-02-23 19:31:25.817    awaiting analysis
#
#                                               Description  CVSS Score  \
# 0       ip_inputc bsdderiv tcpip implement allow remot...         5.0
# 1       buffer overflow nf mountd give root access rem...        10.0
# 2       execut command root via buffer overflow toolta...        10.0
# 3       mime buffer overflow email client eg solari ma...         5.0
# 4       arbitrari command execut via imap buffer overf...        10.0
# ...                                                   ...         ...
# 238603  insuffici sanit mlflow lead xss run recip use ...         NaN
# 238604  reject reason use candid number consultid cve ...         NaN
# 238605  vulner discov verita ediscoveri platform appli...         NaN
# 238606  version packag onnx includ vulner directori tr...         NaN
# 238607  version packag onnx includ vulner outofbound r...         NaN
#
#          Weaknesses                                      Configuration  \
# 0               cwe  cpeobsdibsd_o cpeofreebsdfreebsd cpeofreebsdfr...
# 1               cwe  cpeobsdibsd_o cpeocalderaopenlinux cpeoredhatl...
# 2       nvdcweother  cpeatritrealted_cd cpeosgiirix cpeosgiirix cpe...
# 3       nvdcweother  cpeahpdtmail cpeauniversity_of_washingtonpin c...
# 4       nvdcweother  cpeanetscapemessaging_serv cpeauniversity_of_w...
# ...             ...                                                ...
# 238603          cwe
# 238604
# 238605
# 238606          cwe
# 238607          cwe
#
#                                                References  \
# 0       httpwwwopenbsdorgerratahtmltcpfix httpwwwosvdborg
# 1       ftppatchessgicomsupportfreesecurityadvisoriesi...
# 2       ftppatchessgicomsupportfreesecurityadvisoriesa...
# 3       httpsdocsmicrosoftcomenussecurityupdatessecuri...
# 4       httpsunsolvesuncompubcgiretrievepldoctypecolld...
# ...                                                   ...
# 238603  httpsgithubcommlflowmlflowpul httpsresearchjfr...
# 238604
# 238605           httpswwwveritascomsupporten_ussecurityvt
# 238606  httpsgithubcomonnxonnxcommitbfbfdcfebbddea htt...
# 238607            httpsgithubcomonnxonnxcommitabaababbdeb
#
#                                                  Entities  \
# 0                                                      []
# 1                                         [(mostli, ORG)]
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 238603  [(insuffici sanit mlflow, ORG), (xss, GPE), (j...
# 238604                                                 []
# 238605  [(verita ediscoveri, PERSON), (applic administ...
# 238606                   [(userprovid directori, PERSON)]
# 238607                                  [(one, CARDINAL)]
#
#                                              Dependencies       Category
# 0       [(ip_inputc, compound, bsdderiv), (bsdderiv, c...  vulnerability
# 1       [(buffer, compound, overflow), (overflow, comp...  vulnerability
# 2       [(execut, ROOT, execut), (command, compound, r...  vulnerability
# 3       [(mime, compound, overflow), (buffer, compound...  vulnerability
# 4       [(arbitrari, compound, command), (command, nsu...  vulnerability
# ...                                                   ...            ...
# 238603  [(insuffici, compound, sanit), (sanit, nsubj, ...  vulnerability
# 238604  [(reject, csubj, refer), (reason, nsubj, use),...  vulnerability
# 238605  [(vulner, npadvmod, discov), (discov, compound...  vulnerability
# 238606  [(version, compound, onnx), (packag, compound,...          patch
# 238607  [(version, compound, onnx), (packag, compound,...  vulnerability
#
# [238608 rows x 13 columns]

# %%
pip install sentence-transformers flask pinecone-client pandas scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in e:\maniconda\envs\fai\lib\site-packages (3.2.1)
# Requirement already satisfied: flask in e:\maniconda\envs\fai\lib\site-packages (3.0.3)
# Requirement already satisfied: pinecone-client in e:\maniconda\envs\fai\lib\site-packages (5.0.1)
# Requirement already satisfied: pandas in e:\maniconda\envs\fai\lib\site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in e:\maniconda\envs\fai\lib\site-packages (1.3.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (4.45.2)
# Requirement already satisfied: tqdm in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: scipy in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (0.25.2)
# Requirement already satisfied: Pillow in e:\maniconda\envs\fai\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in e:\maniconda\envs\fai\lib\site-packages (from flask) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in e:\maniconda\envs\fai\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in e:\maniconda\envs\fai\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in e:\maniconda\envs\fai\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in e:\maniconda\envs\fai\lib\site-packages (from flask) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in e:\maniconda\envs\fai\lib\site-packages (from flask) (8.5.0)
# Requirement already satisfied: certifi>=2019.11.17 in e:\maniconda\envs\fai\lib\site-packages (from pinecone-client) (2024.8.30)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in e:\maniconda\envs\fai\lib\site-packages (from pinecone-client) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in e:\maniconda\envs\fai\lib\site-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in e:\maniconda\envs\fai\lib\site-packages (from pinecone-client) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\maniconda\envs\fai\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in e:\maniconda\envs\fai\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.20.3 in e:\maniconda\envs\fai\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: joblib>=1.1.1 in e:\maniconda\envs\fai\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\maniconda\envs\fai\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\imaba\appdata\roaming\python\python38\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: filelock in e:\maniconda\envs\fai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\maniconda\envs\fai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in e:\maniconda\envs\fai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in e:\maniconda\envs\fai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in e:\maniconda\envs\fai\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: zipp>=3.20 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from importlib-metadata>=3.6.0->flask) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\maniconda\envs\fai\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: sympy in e:\maniconda\envs\fai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in e:\maniconda\envs\fai\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: regex!=2019.12.17 in e:\maniconda\envs\fai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in e:\maniconda\envs\fai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in e:\maniconda\envs\fai\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\maniconda\envs\fai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in e:\maniconda\envs\fai\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\maniconda\envs\fai\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import pinecone
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from flask import Flask, jsonify

# %%
import sentence_transformers

# %%
PINECONE_API_KEY = "8c680ba0-9326-43f6-87fe-3aed27c23772cde0135b-6b53-4821-a40a-285e9e324347"
PINECONE_API_ENV = "us-east-1"
PINECONE_INDEX_NAME = "cve-index"

# %%
import os

# %%
# Set the Pinecone API key as an environment variable
os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY

# %%
# Indexing in Pinecone
if PINECONE_INDEX_NAME not in pinecone.list_indexes():
    pinecone.create_index(PINECONE_INDEX_NAME, dimension=768)  # Change dimension based on your embedding model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Indexing in Pinecone
# ----> 2 if PINECONE_INDEX_NAME not in pinecone.list_indexes():
#       3     pinecone.create_index(PINECONE_INDEX_NAME, dimension=768)  # Change dimension based on your embedding model
#
# File e:\maniconda\envs\fai\lib\site-packages\pinecone\deprecation_warnings.py:53, in list_indexes(*args, **kwargs)
#      42 def list_indexes(*args, **kwargs):
#      43     example = """
#      44     from pinecone import Pinecone
#      45
#    (...)
#      51         # do something
#      52 """
# ---> 53     raise AttributeError(_build_class_migration_message("list_indexes", example))
#
# AttributeError: list_indexes is no longer a top-level attribute of the pinecone package.
#
# To use list_indexes, please create a client instance and call the method there instead.
#
# Example:
#
#     from pinecone import Pinecone
#
#     pc = Pinecone(api_key='YOUR_API_KEY')
#
#     index_name = "quickstart" # or your index name
#
#     if index_name not in pc.list_indexes().names():
#         # do something

# %%
import pandas as pd
import pinecone
from sentence_transformers import SentenceTransformer
from flask import Flask, jsonify

# Initialize Pinecone
PINECONE_API_KEY = "8c680ba0-9326-43f6-87fe-3aed27c23772cde0135b-6b53-4821-a40a-285e9e324347"
PINECONE_API_ENV = "us-east-1"
PINECONE_INDEX_NAME = "cve-index"

# %%
existing_indexes = pinecone.list_indexes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 existing_indexes = pinecone.list_indexes()
#
# File e:\maniconda\envs\fai\lib\site-packages\pinecone\deprecation_warnings.py:53, in list_indexes(*args, **kwargs)
#      42 def list_indexes(*args, **kwargs):
#      43     example = """
#      44     from pinecone import Pinecone
#      45
#    (...)
#      51         # do something
#      52 """
# ---> 53     raise AttributeError(_build_class_migration_message("list_indexes", example))
#
# AttributeError: list_indexes is no longer a top-level attribute of the pinecone package.
#
# To use list_indexes, please create a client instance and call the method there instead.
#
# Example:
#
#     from pinecone import Pinecone
#
#     pc = Pinecone(api_key='YOUR_API_KEY')
#
#     index_name = "quickstart" # or your index name
#
#     if index_name not in pc.list_indexes().names():
#         # do something

# %%
pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_API_ENV)

# %%
pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in e:\maniconda\envs\fai\lib\site-packages (0.2.17)
# Requirement already satisfied: PyYAML>=5.3 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (0.2.16)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.39 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (0.2.41)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (1.24.4)
# Requirement already satisfied: requests<3,>=2 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in e:\maniconda\envs\fai\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.15.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in e:\maniconda\envs\fai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\maniconda\envs\fai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\maniconda\envs\fai\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in e:\maniconda\envs\fai\lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in e:\maniconda\envs\fai\lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (1.10.18)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\maniconda\envs\fai\lib\site-packages (from langchain-core<0.3.0,>=0.2.39->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in e:\maniconda\envs\fai\lib\site-packages (from langchain-core<0.3.0,>=0.2.39->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\imaba\appdata\roaming\python\python38\site-packages (from langchain-core<0.3.0,>=0.2.39->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\maniconda\envs\fai\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\maniconda\envs\fai\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in e:\maniconda\envs\fai\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\maniconda\envs\fai\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in e:\maniconda\envs\fai\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\maniconda\envs\fai\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\maniconda\envs\fai\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in e:\maniconda\envs\fai\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in e:\maniconda\envs\fai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (4.5.2)
# Requirement already satisfied: httpcore==1.* in e:\maniconda\envs\fai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in e:\maniconda\envs\fai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\maniconda\envs\fai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\maniconda\envs\fai\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.39->langchain-community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\maniconda\envs\fai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in e:\maniconda\envs\fai\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\maniconda\envs\fai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import CTransformers
from pinecone import Pinecone, ServerlessSpec 
import pinecone

# %%
from langchain_pinecone import PineconeVectorStore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain_pinecone import PineconeVectorStore
#
# ModuleNotFoundError: No module named 'langchain_pinecone'

# %%
pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_API_ENV)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_API_ENV)
#
# File e:\maniconda\envs\fai\lib\site-packages\pinecone\deprecation_warnings.py:39, in init(*args, **kwargs)
#      12     example = """
#      13     import os
#      14     from pinecone import Pinecone, ServerlessSpec
#    (...)
#      30         )
#      31 """
#      32     msg = f"""init is no longer a top-level attribute of the pinecone package.
#      33
#      34 Please create an instance of the Pinecone class instead.
#    (...)
#      37 {example}
#      38 """
# ---> 39     raise AttributeError(msg)
#
# AttributeError: init is no longer a top-level attribute of the pinecone package.
#
# Please create an instance of the Pinecone class instead.
#
# Example:
#
#     import os
#     from pinecone import Pinecone, ServerlessSpec
#
#     pc = Pinecone(
#         api_key=os.environ.get("PINECONE_API_KEY")
#     )
#
#     # Now do stuff
#     if 'my_index' not in pc.list_indexes().names():
#         pc.create_index(
#             name='my_index',
#             dimension=1536,
#             metric='euclidean',
#             spec=ServerlessSpec(
#                 cloud='aws',
#                 region='us-west-2'
#             )
#         )

# %%
# Check if the index exists; if not, create it
if PINECONE_INDEX_NAME not in pinecone.list_indexes():
    pinecone.create_index(PINECONE_INDEX_NAME, dimension=768)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Check if the index exists; if not, create it
# ----> 2 if PINECONE_INDEX_NAME not in pinecone.list_indexes():
#       3     pinecone.create_index(PINECONE_INDEX_NAME, dimension=768)
#
# File e:\maniconda\envs\fai\lib\site-packages\pinecone\deprecation_warnings.py:53, in list_indexes(*args, **kwargs)
#      42 def list_indexes(*args, **kwargs):
#      43     example = """
#      44     from pinecone import Pinecone
#      45
#    (...)
#      51         # do something
#      52 """
# ---> 53     raise AttributeError(_build_class_migration_message("list_indexes", example))
#
# AttributeError: list_indexes is no longer a top-level attribute of the pinecone package.
#
# To use list_indexes, please create a client instance and call the method there instead.
#
# Example:
#
#     from pinecone import Pinecone
#
#     pc = Pinecone(api_key='YOUR_API_KEY')
#
#     index_name = "quickstart" # or your index name
#
#     if index_name not in pc.list_indexes().names():
#         # do something

# %%
# Initialize Pinecone
pinecone.init(api_key='YOUR_PINECONE_API_KEY', environment='us-west1-gcp')
index_name = "cve-index"
if index_name not in pinecone.list_indexes():
    pinecone.create_index(index_name, dimension=768)  # Use the appropriate dimension for your embeddings
index = pinecone.Index(index_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Initialize Pinecone
# ----> 2 pinecone.init(api_key='YOUR_PINECONE_API_KEY', environment='us-west1-gcp')
#       3 index_name = "cve-index"
#       4 if index_name not in pinecone.list_indexes():
#
# File e:\maniconda\envs\fai\lib\site-packages\pinecone\deprecation_warnings.py:39, in init(*args, **kwargs)
#      12     example = """
#      13     import os
#      14     from pinecone import Pinecone, ServerlessSpec
#    (...)
#      30         )
#      31 """
#      32     msg = f"""init is no longer a top-level attribute of the pinecone package.
#      33
#      34 Please create an instance of the Pinecone class instead.
#    (...)
#      37 {example}
#      38 """
# ---> 39     raise AttributeError(msg)
#
# AttributeError: init is no longer a top-level attribute of the pinecone package.
#
# Please create an instance of the Pinecone class instead.
#
# Example:
#
#     import os
#     from pinecone import Pinecone, ServerlessSpec
#
#     pc = Pinecone(
#         api_key=os.environ.get("PINECONE_API_KEY")
#     )
#
#     # Now do stuff
#     if 'my_index' not in pc.list_indexes().names():
#         pc.create_index(
#             name='my_index',
#             dimension=1536,
#             metric='euclidean',
#             spec=ServerlessSpec(
#                 cloud='aws',
#                 region='us-west-2'
#             )
#         )

# %%
'''import pandas as pd
import re
import requests
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from datetime import datetime
import json
import pinecone
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk import word_tokenize, pos_tag, ne_chunk

# Initialize NLTK resources
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# Define stop words and stemmer
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

# Step 1: Data Collection (Assuming CSV data is already downloaded)
# Load the CVE data CSV file
df = pd.read_csv("cve_data.csv")

# Step 2: Data Preprocessing
# Preprocessing function for text fields
def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    text = ' '.join([ps.stem(word) for word in text.split() if word not in stop_words])
    return text

# Apply preprocessing to textual columns
for column in ['Description', 'Weaknesses', 'Configuration', 'References']:
    df[column] = df[column].apply(preprocess_text)

# Standardize 'CVE ID' and 'Source Identifier'
df['CVE ID'] = df['CVE ID'].str.upper().str.strip()
df['Source Identifier'] = df['Source Identifier'].str.strip()
df['Vulnerability Status'] = df['Vulnerability Status'].str.lower().str.strip()

# Convert 'CVSS Score' to numeric
df['CVSS Score'] = pd.to_numeric(df['CVSS Score'], errors='coerce')

# Convert date fields to datetime
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce')
df['Last Modified Date'] = pd.to_datetime(df['Last Modified Date'], errors='coerce')

# Drop rows missing critical information
df.dropna(subset=['CVE ID', 'Source Identifier', 'Description'], inplace=True)

# Save preprocessed data for further analysis
df.to_csv("cve_data_preprocessed.csv", index=False)

print("Data Preprocessing Complete!")

# Step 3: Information Extraction (Using Named Entity Recognition)
def extract_entities(text):
    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    entities = ne_chunk(tagged)
    return entities

# Apply NER on 'Description' column for demonstration
df['Entities'] = df['Description'].apply(extract_entities)

# Step 4: Text Classification (Using TF-IDF and Cosine Similarity)
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['Description'])

# Function to classify based on similarity
def classify_text(query):
    query_vector = vectorizer.transform([query])
    cosine_sim = cosine_similarity(query_vector, tfidf_matrix).flatten()
    most_similar_index = cosine_sim.argmax()
    return df.iloc[most_similar_index]

# Test Classification
sample_query = "remote code execution vulnerability in windows"
result = classify_text(sample_query)
print("Classification Result:", result[['CVE ID', 'Description']])

# Step 5: Store and Access Data in Pinecone for Fast Retrieval
pinecone.init(api_key="YOUR_PINECONE_API_KEY", environment="us-east-1")  # Replace with actual Pinecone API key

# Create a Pinecone index
index_name = "cve_index"
if index_name not in pinecone.list_indexes():
    pinecone.create_index(index_name, dimension=tfidf_matrix.shape[1])

# Connect to the index
index = pinecone.Index(index_name)

# Upsert (Upload) data to Pinecone index
for i, row in df.iterrows():
    vector = tfidf_matrix[i].toarray().flatten().tolist()
    metadata = {
        "CVE ID": row["CVE ID"],
        "Source Identifier": row["Source Identifier"],
        "Published Date": str(row["Published Date"]),
        "Description": row["Description"]
    }
    index.upsert([(row["CVE ID"], vector, metadata)])

# Step 6: Advanced Analysis - Trend Analysis (e.g., CVSS Score Trend Over Time)
trend_data = df[['Published Date', 'CVSS Score']].dropna()
trend_data.set_index('Published Date', inplace=True)
trend_data = trend_data.resample('Y').mean()  # Annual average CVSS score

# Plotting (Optional)
import matplotlib.pyplot as plt
plt.plot(trend_data.index, trend_data['CVSS Score'], marker='o')
plt.title("Average CVSS Score Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Average CVSS Score")
plt.show()

print("Pipeline Completed!")


isko dekhna ek bbare preprocessing tk'''
# Out:
# 'import pandas as pd\nimport re\nimport requests\nfrom nltk.corpus import stopwords\nfrom nltk.stem import PorterStemmer\nfrom datetime import datetime\nimport json\nimport pinecone\nfrom sklearn.feature_extraction.text import TfidfVectorizer\nfrom sklearn.metrics.pairwise import cosine_similarity\nfrom nltk import word_tokenize, pos_tag, ne_chunk\n\n# Initialize NLTK resources\nimport nltk\nnltk.download(\'stopwords\')\nnltk.download(\'punkt\')\nnltk.download(\'maxent_ne_chunker\')\nnltk.download(\'words\')\n\n# Define stop words and stemmer\nstop_words = set(stopwords.words(\'english\'))\nps = PorterStemmer()\n\n# Step 1: Data Collection (Assuming CSV data is already downloaded)\n# Load the CVE data CSV file\ndf = pd.read_csv("cve_data.csv")\n\n# Step 2: Data Preprocessing\n# Preprocessing function for text fields\ndef preprocess_text(text):\n    if pd.isna(text):\n        return ""\n    text = text.lower()\n    text = re.sub(r\'\\d+\', \'\', text)  # Remove digits\n    text = re.sub(r\'[^\\w\\s]\', \'\', text)  # Remove punctuation\n    text = re.sub(r\'\\s+\', \' \', text).strip()  # Remove extra spaces\n    text = \' \'.join([ps.stem(word) for word in text.split() if word not in stop_words])\n    return text\n\n# Apply preprocessing to textual columns\nfor column in [\'Description\', \'Weaknesses\', \'Configuration\', \'References\']:\n    df[column] = df[column].apply(preprocess_text)\n\n# Standardize \'CVE ID\' and \'Source Identifier\'\ndf[\'CVE ID\'] = df[\'CVE ID\'].str.upper().str.strip()\ndf[\'Source Identifier\'] = df[\'Source Identifier\'].str.strip()\ndf[\'Vulnerability Status\'] = df[\'Vulnerability Status\'].str.lower().str.strip()\n\n# Convert \'CVSS Score\' to numeric\ndf[\'CVSS Score\'] = pd.to_numeric(df[\'CVSS Score\'], errors=\'coerce\')\n\n# Convert date fields to datetime\ndf[\'Published Date\'] = pd.to_datetime(df[\'Published Date\'], errors=\'coerce\')\ndf[\'Last Modified Date\'] = pd.to_datetime(df[\'Last Modified Date\'], errors=\'coerce\')\n\n# Drop rows missing critical information\ndf.dropna(subset=[\'CVE ID\', \'Source Identifier\', \'Description\'], inplace=True)\n\n# Save preprocessed data for further analysis\ndf.to_csv("cve_data_preprocessed.csv", index=False)\n\nprint("Data Preprocessing Complete!")\n\n# Step 3: Information Extraction (Using Named Entity Recognition)\ndef extract_entities(text):\n    tokens = word_tokenize(text)\n    tagged = pos_tag(tokens)\n    entities = ne_chunk(tagged)\n    return entities\n\n# Apply NER on \'Description\' column for demonstration\ndf[\'Entities\'] = df[\'Description\'].apply(extract_entities)\n\n# Step 4: Text Classification (Using TF-IDF and Cosine Similarity)\nvectorizer = TfidfVectorizer()\ntfidf_matrix = vectorizer.fit_transform(df[\'Description\'])\n\n# Function to classify based on similarity\ndef classify_text(query):\n    query_vector = vectorizer.transform([query])\n    cosine_sim = cosine_similarity(query_vector, tfidf_matrix).flatten()\n    most_similar_index = cosine_sim.argmax()\n    return df.iloc[most_similar_index]\n\n# Test Classification\nsample_query = "remote code execution vulnerability in windows"\nresult = classify_text(sample_query)\nprint("Classification Result:", result[[\'CVE ID\', \'Description\']])\n\n# Step 5: Store and Access Data in Pinecone for Fast Retrieval\npinecone.init(api_key="YOUR_PINECONE_API_KEY", environment="us-east-1")  # Replace with actual Pinecone API key\n\n# Create a Pinecone index\nindex_name = "cve_index"\nif index_name not in pinecone.list_indexes():\n    pinecone.create_index(index_name, dimension=tfidf_matrix.shape[1])\n\n# Connect to the index\nindex = pinecone.Index(index_name)\n\n# Upsert (Upload) data to Pinecone index\nfor i, row in df.iterrows():\n    vector = tfidf_matrix[i].toarray().flatten().tolist()\n    metadata = {\n        "CVE ID": row["CVE ID"],\n        "Source Identifier": row["Source Identifier"],\n        "Published Date": str(row["Published Date"]),\n        "Description": ro ...
